# %%
nex_path = '/media/SOLabNFS2/store/satellite/nasanex/NEX-GDDP/BCSD/rcp85/day/atmos/pr/r1i1p1/v1.0/'

# %%
# %pylab inline
import sys
import os
from netCDF4 import Dataset as ncDataset
from pylab import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for _dir, _subdir, _files in os.walk(nex_path):
    print _dir, _subdir, _files
# Out:
# /media/SOLabNFS2/store/satellite/nasanex/NEX-GDDP/BCSD/rcp85/day/atmos/pr/r1i1p1/v1.0/ [] ['pr_day_BCSD_rcp85_r1i1p1_inmcm4_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_bcc-csm1-1_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_NorESM1-M_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_ACCESS1-0_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_ACCESS1-0_2098.nc', 'pr_day_BCSD_rcp85_r1i1p1_BNU-ESM_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_BNU-ESM_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_CCSM4_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_CCSM4_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_CESM1-BGC_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_CESM1-BGC_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_CNRM-CM5_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_CNRM-CM5_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_CSIRO-Mk3-6-0_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_CSIRO-Mk3-6-0_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_CanESM2_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_CanESM2_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_GFDL-CM3_2100.nc', 'pr_day_BCSD_rcp85_r1i1p1_GFDL-CM3_2099.nc', 'pr_day_BCSD_rcp85_r1i1p1_GFDL-ESM2G_2100.nc', 
# ...

# %%
fn = 'pr_day_BCSD_rcp85_r1i1p1_inmcm4_2100.nc'
dataset = ncDataset(os.path.join(nex_path, fn))

var = dataset.variables['pr']

print var.getncattr('long_name')
print var.getncattr('comment')
values = var[56, :, :]
imshow(values)
show()
values = var[30, :, :]
imshow(values)
show()
# Out:
# Precipitation
# at surface; includes both liquid and solid phases from all types of clouds (both large-scale and convective)

# %%
fn = 'pr_day_BCSD_rcp85_r1i1p1_NorESM1-M_2100.nc'
dataset = ncDataset(os.path.join(nex_path, fn))

var = dataset.variables['pr']

print var.getncattr('long_name')
print var.getncattr('comment')
values = var[56, :, :]
imshow(values)
colorbar()
show()
values = var[30, :, :]
imshow(values)
colorbar()
show()
# Out:
# Precipitation
# at surface; includes both liquid and solid phases from all types of clouds (both large-scale and convective)

# %%
fn = 'pr_day_BCSD_rcp85_r1i1p1_ACCESS1-0_2098.nc'
dataset = ncDataset(os.path.join(nex_path, fn))

var = dataset.variables['pr']

print var.getncattr('long_name')
print var.getncattr('comment')
values = var[56, :, :]
imshow(values)
show()
values = var[30, :, :]
imshow(values)
show()
# Out:
# Precipitation
# at surface; includes both liquid and solid phases from all types of clouds (both large-scale and convective)

# %%
fn = 'pr_day_BCSD_rcp85_r1i1p1_MPI-ESM-LR_2100.nc'
dataset = ncDataset(os.path.join(nex_path, fn))

var = dataset.variables['pr']

print var.getncattr('long_name')
print var.getncattr('comment')
values = var[56, :, :]
imshow(values, vmin=0, vmax=0.0005)
show()
values = var[30, :, :]
imshow(values)
show()
# Out:
# Precipitation
# at surface; includes both liquid and solid phases from all types of clouds (both large-scale and convective)
