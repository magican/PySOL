# %%
from pydap.client import open_url
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

link = "http://opendap.solab.rshu.ru:8080/opendap/allData/QSCAT_L2B12/2007/008/QS_S2B39346.20070092335.CP12.gz"
# dataset = open_url(link)
# wind_speed = dataset.wind_speed[:,:]
# lat = dataset.wvc_lat[:]
# lon = dataset.wvc_lon[:]

scale_factor = dataset.wvc_lat.scale_factor

lat = lat*scale_factor
lon = lon*scale_factor


wind_speed = np.ma.array(wind_speed, mask = (wind_speed < 0), copy = True)
wind_speed = np.ma.array(wind_speed, mask = (wind_speed > 5000), copy = True)

m = Basemap(projection='merc',llcrnrlat=-80,urcrnrlat=80,\
            llcrnrlon=-180,urcrnrlon=180,lat_ts=20,resolution='c')

x,y = m(lon,lat)

# m.drawcoastlines()
# m.fillcontinents(color='coral',lake_color='aqua')
# m.drawparallels(np.arange(-90.,91.,30.))
# m.drawmeridians(np.arange(-180.,181.,60.))
# m.drawmapboundary(fill_color='aqua')

im = m.pcolor(x, y, reshape(wind_speed[:,:,0], (3248, 152)), shading='flat', cmap=cm.jet)

# %%
reshape(wind_speed[:,:,0], (3248, 152)).max()
# Out:
# 4995
