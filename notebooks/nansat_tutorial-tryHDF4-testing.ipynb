# %%
# %install_ext https://raw.github.com/minrk/ipython_extensions/master/nbtoc.py
# Out:
# Installed nbtoc.py. To use it, type:
#   %load_ext nbtoc

# %%
# %reload_ext nbtoc
# %nbtoc
# Out:
# <!-- extracted from https://gist.github.com/magican/5574556 -->
# <div id="toc-wrapper">
#     <div class="header">Contents <a href="#" class="hide-btn">[hide]</a></div>
#     <div id="toc"></div>
# </div>
#
# <style>
#   #toc {
#     overflow-y: scroll;
#     max-height: 300px;
#   }
#   #toc-wrapper {
#     position: fixed; top: 120px; max-width:430px; right: 20px;
#     border: thin solid rgba(0, 0, 0, 0.38); opacity: .8;
#     border-radius: 5px; background-color: #fff; padding:10px;
#     z-index: 100;
#   }
#   #toc-wrapper.closed {
#       min-width: 100px;
#       width: auto;
#       transition: width;
#   }
#   #toc-wrapper:hover{
#       opacity:1;
#   }
#   #toc-wrapper .header {
#       font-size:18px; font-weight: bold;
#   }
#   #toc-wrapper .hide-btn {
#       font-size: 14px;
#   }
#
# </style>
#
# <style>
#   ol.nested {
#     counter-reset: item;
#     list-style: none;
#   }
#   li.nested {
#         display: block;
#     }
#   li.nested:before {
#         counter-increment: item;
#         content: counters(item, ".")" ";
#     }
# </style>

# %% [markdown]
# # Nansat is a scientist friendly Python toolbox for satellite data processing.

# %% [raw]
# This is an ipynb version of the official Nansat tutorial with examples and exhaustive explanations

# %% [raw]
# #!/usr/bin/env python
# # Name:    tutorial.py
# # Purpose: Tutorial with list of examples
# # Authors:      Asuka Yamakawa, Anton Korosov, Knut-Frode Dagestad,
# #               Morten W. Hansen, Alexander Myasoyedov,
# #               Dmitry Petrenko, Evgeny Morozov
# # Created:      29.06.2011
# # Copyright:    (c) NERSC 2011 - 2013
# # Licence:
# # This file is part of NANSAT.
# # NANSAT is free software: you can redistribute it and/or modify
# # it under the terms of the GNU General Public License as published by
# # the Free Software Foundation, version 3 of the License.
# # http://www.gnu.org/licenses/gpl-3.0.html
# # This program is distributed in the hope that it will be useful,
# # but WITHOUT ANY WARRANTY without even the implied warranty of
# # MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %% [markdown]
# ### First we import the libraries

# %%
import Image # further needed to show the saved images

import numpy as np
import matplotlib.pyplot as plt
from scipy.io import savemat
import inspect, os

from nansat import Nansat, Domain

# %% [markdown]
# ### Setting the Input and Output file names

# %% [raw]
# All the examples are shown with the image 'gcps.tif'. All the output data and images are saved in the 'tmdata' folder

# %%
# input and output file names
iPath = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
iFileName = os.path.join(iPath, 'gcps.tif')
print 'Input file: ', iFileName
oFileName = os.path.join(iPath, 'tmpdata', 'output_')
print 'Output file prefix: ', oFileName
# Out:
# Input file:  /home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif
# Output file prefix:  /home/mag/Documents/repos/solab/PySOL/notebooks/tmpdata/output_

# %% [markdown]
# ### Open an input file, specify which Mapper to use and set the logging level

# %%
# Create a Nansat object <n> for futher high-level operations
n = Nansat(iFileName, mapperName='generic', logLevel=1)
# Out:
# 11:38:51|10|nansat|__init__|Mappers: []
# DEBUG:Nansat:Mappers: []
# 11:38:51|10|vrt|__init__|VRT self.dataset: <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0xba4bae0> >
# DEBUG:Nansat:VRT self.dataset: <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0xba4bae0> >
# 11:38:51|10|vrt|__init__|VRT description: /vsimem/I5A80XBL99.vrt
# DEBUG:Nansat:VRT description: /vsimem/I5A80XBL99.vrt
# 11:38:51|10|vrt|__init__|VRT RasterXSize 200
# DEBUG:Nansat:VRT RasterXSize 200
# 11:38:51|10|vrt|__init__|VRT RasterYSize 200
# DEBUG:Nansat:VRT RasterYSize 200
# 11:38:51|10|vrt|_create_band|INPUTS: {'SourceBand': 1, 'ScaleRatio': '0.203921568627', 'DataType': 1, 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif'}, {'name': 'L_645', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'time': '2011-08-15 10:05:00', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'} "
# DEBUG:Nansat:INPUTS: {'SourceBand': 1, 'ScaleRatio': '0.203921568627', 'DataType': 1, 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif'}, {'name': 'L_645', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'time': '2011-08-15 10:05:00', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'} "
# 11:38:51|10|vrt|_create_band|Options of AddBand: []
# DEBUG:Nansat:Options of AddBand: []
# 11:38:51|10|vrt|_create_band|wkvDict:{'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# DEBUG:Nansat:wkvDict:{'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# 11:38:51|10|vrt|_create_band|WKV short_name:nLw
# DEBUG:Nansat:WKV short_name:nLw
# 11:38:51|10|vrt|_create_band|dst[name]:L_645
# DEBUG:Nansat:dst[name]:L_645
# 11:38:51|10|vrt|_put_metadata|Put: {'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# DEBUG:Nansat:Put: {'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# 11:38:51|10|vrt|_put_metadata|Put: {'name': 'L_645', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'SourceBand': '1', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'}
# DEBUG:Nansat:Put: {'name': 'L_645', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'SourceBand': '1', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'}
# 11:38:51|10|vrt|_create_bands|Creating band - OK!
# DEBUG:Nansat:Creating band - OK!
# 11:38:51|10|vrt|_create_band|INPUTS: {'SourceBand': 2, 'ScaleRatio': '0.227450980392', 'DataType': 1, 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif'}, {'name': 'L_555', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'time': '2011-08-15 10:05:00', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'} "
# DEBUG:Nansat:INPUTS: {'SourceBand': 2, 'ScaleRatio': '0.227450980392', 'DataType': 1, 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif'}, {'name': 'L_555', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'time': '2011-08-15 10:05:00', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'} "
# 11:38:51|10|vrt|_create_band|Options of AddBand: []
# DEBUG:Nansat:Options of AddBand: []
# 11:38:51|10|vrt|_create_band|wkvDict:{'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# DEBUG:Nansat:wkvDict:{'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# 11:38:51|10|vrt|_create_band|WKV short_name:nLw
# DEBUG:Nansat:WKV short_name:nLw
# 11:38:51|10|vrt|_create_band|dst[name]:L_555
# DEBUG:Nansat:dst[name]:L_555
# 11:38:51|10|vrt|_put_metadata|Put: {'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# DEBUG:Nansat:Put: {'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# 11:38:51|10|vrt|_put_metadata|Put: {'name': 'L_555', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'SourceBand': '2', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'}
# DEBUG:Nansat:Put: {'name': 'L_555', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'SourceBand': '2', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'}
# 11:38:51|10|vrt|_create_bands|Creating band - OK!
# DEBUG:Nansat:Creating band - OK!
# 11:38:51|10|vrt|_create_band|INPUTS: {'SourceBand': 3, 'ScaleRatio': '0.329411764706', 'DataType': 1, 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif'}, {'name': 'L_469', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'time': '2011-08-15 10:05:00', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'} "
# DEBUG:Nansat:INPUTS: {'SourceBand': 3, 'ScaleRatio': '0.329411764706', 'DataType': 1, 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif'}, {'name': 'L_469', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'time': '2011-08-15 10:05:00', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'} "
# 11:38:51|10|vrt|_create_band|Options of AddBand: []
# DEBUG:Nansat:Options of AddBand: []
# 11:38:51|10|vrt|_create_band|wkvDict:{'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# DEBUG:Nansat:wkvDict:{'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# 11:38:51|10|vrt|_create_band|WKV short_name:nLw
# DEBUG:Nansat:WKV short_name:nLw
# 11:38:51|10|vrt|_create_band|dst[name]:L_469
# DEBUG:Nansat:dst[name]:L_469
# 11:38:51|10|vrt|_put_metadata|Put: {'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# DEBUG:Nansat:Put: {'colormap': 'jet', 'minmax': '0.000 500', 'short_name': 'nLw', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'units': 'W m-2 m-1 sr-1'}
# 11:38:51|10|vrt|_put_metadata|Put: {'name': 'L_469', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'SourceBand': '3', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'}
# DEBUG:Nansat:Put: {'name': 'L_469', 'dataType': '1', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'SourceBand': '3', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water'}
# 11:38:51|10|vrt|_create_bands|Creating band - OK!
# DEBUG:Nansat:Creating band - OK!
# 11:38:51|10|vrt|__init__|copy content of the provided VRT dataset using CreateCopy
# DEBUG:Nansat:copy content of the provided VRT dataset using CreateCopy
# 11:38:51|10|vrt|__init__|VRT self.dataset: <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0xba4cea0> >
# DEBUG:Nansat:VRT self.dataset: <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0xba4cea0> >
# 11:38:51|10|vrt|__init__|VRT description: /vsimem/84PTJI2DU5.vrt
# DEBUG:Nansat:VRT description: /vsimem/84PTJI2DU5.vrt
# 11:38:51|10|vrt|__init__|VRT RasterXSize 200
# DEBUG:Nansat:VRT RasterXSize 200
# 11:38:51|10|vrt|__init__|VRT RasterYSize 200
# DEBUG:Nansat:VRT RasterYSize 200
# 11:38:51|10|nansat|__init__|Object created from /home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif
# DEBUG:Nansat:Object created from /home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif

# %% [raw]
# Further we reopen the same input file without logging, not to flood.
# One can notice that we don't set the Mapper specification as well. So the Nansat chooses the appropriate Mapper itself.

# %%
# Open an input file without logging
n = Nansat(iFileName)

# %%
# list bands and georeference of the object
print 'Raw Nansat:', n
# Out:
# Raw Nansat: ----------------------------------------
# /home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif
# ----------------------------------------
# Mapper: mapper_generic
# ----------------------------------------
# Band : 1 L_645
#   units: W m-2 m-1 sr-1
#   colormap: jet
#   short_name: nLw
#   dataType: 1
#   long_name: Upward spectral radiance
#   standard_name: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   SourceFilename: /home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif
#   time: 2011-08-15 10:05:00
#   minmax: 0.000 500
#   SourceBand: 1
#   wkv: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   name: L_645
# Band : 2 L_555
#   units: W m-2 m-1 sr-1
#   colormap: jet
#   short_name: nLw
#   dataType: 1
#   long_name: Upward spectral radiance
#   standard_name: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   SourceFilename: /home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif
#   time: 2011-08-15 10:05:00
#   minmax: 0.000 500
#   SourceBand: 2
#   wkv: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   name: L_555
# Band : 3 L_469
#   units: W m-2 m-1 sr-1
#   colormap: jet
#   short_name: nLw
#   dataType: 1
#   long_name: Upward spectral radiance
#   standard_name: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   SourceFilename: /home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif
#   time: 2011-08-15 10:05:00
#   minmax: 0.000 500
#   SourceBand: 3
#   wkv: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   name: L_469
# ----------------------------------------
# Domain:[200 x 200]
# ----------------------------------------
# Projection:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563],
#         TOWGS84[0,0,0,0,0,0,0]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433]]
# ----------------------------------------
# Corners (lon, lat):
# 	 ( 28.25,  71.54)  ( 30.87,  71.17)
# 	 ( 27.14,  70.72)  ( 29.68,  70.35)

# %%
# get dictionary with metadata from all bands
print 'Bands:', n.bands()
# Out:
# Bands: {1: {'units': 'W m-2 m-1 sr-1', 'colormap': 'jet', 'short_name': 'nLw', 'dataType': '1', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'minmax': '0.000 500', 'SourceBand': '1', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'name': 'L_645'}, 2: {'units': 'W m-2 m-1 sr-1', 'colormap': 'jet', 'short_name': 'nLw', 'dataType': '1', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'minmax': '0.000 500', 'SourceBand': '2', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'name': 'L_555'}, 3: {'units': 'W m-2 m-1 sr-1', 'colormap': 'jet', 'short_name': 'nLw', 'dataType': '1', 'long_name': 'Upward spectral radiance', 'standard_name': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'SourceFilename': '/home/mag/Documents/repos/solab/PySOL/notebooks/gcps.tif', 'time': '2011-08-15 10:05:00', 'minmax': '0.000 500', 'SourceBand': '3', 'wkv': 'surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water', 'name': 'L_469'}}

# %%
# get size of the object (Y and X dimensions, to follow Numpy style)
print 'Shape:', n.shape()
# Out:
# Shape: (200, 200)

# %%
# get list with coordinates of the object corners
print 'Corners:', n.get_corners()
# Out:
# Corners: ([28.24601167198886, 27.138912696613616, 30.872243884540733, 29.67614139440522], [71.54332382913086, 70.71647224898452, 71.16606384662718, 70.35441758672405])

# %%
# get lists with coordinates of the object borders
print 'Border:', n.get_border()
# Out:
# Border: ([28.24601167198886, 28.51764156905009, 28.78726998259887, 29.05489691263519, 29.32052235915906, 29.584146322170476, 29.845768801669436, 30.105389797655942, 30.363009310129996, 30.618627339091592, 30.872243884540733, 30.872243884540733, 30.748439857055974, 30.625567780342585, 30.50362765440059, 30.382619479229966, 30.262543254830724, 30.143398981202864, 30.02518665834638, 29.90790628626128, 29.79155786494756, 29.67614139440522, 29.67614139440522, 29.431425200432102, 29.18470752294654, 28.93598836194851, 28.68526771743803, 28.4325455894151, 28.17782197787971, 27.921096882831865, 27.662370304271573, 27.401642242198825, 27.138912696613616, 27.138912696613616, 27.245428815679933, 27.352876885517624, 27.4612569061267, 27.570568877507153, 27.680812799658987, 27.791988672582203, 27.904096496276797, 28.017136270742768, 28.131107995980127, 28.24601167198886], [71.54332382913086, 71.50657734110082, 71.46961318413295, 71.43243135822722, 71.39503186338361, 71.35741469960217, 71.31957986688288, 71.28152736522574, 71.24325719463073, 71.20476935509788, 71.16606384662718, 71.16606384662718, 71.08520402361783, 71.00427646661272, 70.92328117561182, 70.84221815061517, 70.76108739162274, 70.67988889863454, 70.59862267165059, 70.51728871067083, 70.43588701569533, 70.35441758672405, 70.35441758672405, 70.39160256317044, 70.42856987067896, 70.46531950924965, 70.50185147888246, 70.53816577957744, 70.57426241133456, 70.61014137415384, 70.64580266803526, 70.6812462929788, 70.71647224898452, 70.71647224898452, 70.7994622099801, 70.88238443697993, 70.96523892998401, 71.0480256889923, 71.1307447140048, 71.21339600502155, 71.29597956204253, 71.37849538506775, 71.46094347409719, 71.54332382913086])

# %%
# get time of the image aquisition
print 'Time:', n.get_time()[0]
# Out:
# Time: 2011-08-15 10:05:00

# %%
# Get band data and do some operations
# 1. Get data from 1st band as numpy array
# 2. Plot the array (pyplot image is save to a PNG file)
# 3. Save as Matlab file
a = n[1]
plt.imshow(a);plt.colorbar();plt.savefig(oFileName + '_imshow.png');plt.close()
savemat(oFileName + '.mat', {'band_1': a})

# open the saved image to show it
im = Image.open(oFileName + '_imshow.png')
plt.imshow(im)

# %%
# make simple indexed image from 1st band with default colormap
n.write_figure(oFileName + '.png')

# open the saved image to show it
im = Image.open(oFileName + '.png')
plt.imshow(im)

# %%
# make RGB image from bands 1,2,3 with brightness correction
n.write_figure(oFileName + '_rgb.png', bands=[1,2,3], clim='hist', ratio=0.9)

# open the saved image to show it
im = Image.open(oFileName + '_rgb.png')
plt.imshow(im)

# %%
# make indexed image with legend
n.write_figure(oFileName + '_legend.png', legend=True, titleString='NANSAT Tutorial', LEGEND_HEIGHT=0.3, fontSize=10)

# open the saved image to show it
im = Image.open(oFileName + '_legend.png')
plt.imshow(im)

# %%
# get array with watermask (landmask)
# 1. Get Nansat object with watermask
# 2. Get array from Nansat object. 0 - land, 1 - water
wm = n.watermask()
wmArray = wm[1]

# write figure with land overlay (gray color) and apply brightness gamma correction
n.write_figure(oFileName + '_land.png', clim='hist', mask_array=wmArray, mask_lut={0: [128, 128, 128]}, logarithm=True, gamma=3)

# open the saved image to show it
im = Image.open(oFileName + '_land.png')
plt.imshow(im)

# %%
# add logo to image to the lower left corner
# (make sure file is in the current folder)
n.write_figure(oFileName + '_logo.png', logoFileName='nansat_logo_s.png', logoLocation=[10, -10], logoSize=[70, 70])

# open the saved image to show it
im = Image.open(oFileName + '_logo.png')
plt.imshow(im)

# %%
# write figure with lat/lon grid
# 1. Get lat/lon arrays from Nansat object (may take some time)
# 2. Make figure with lat/lon grids
lonGrid, latGrid = n.get_geolocation_grids()
n.write_figure(oFileName + '_latlon.png', latGrid=latGrid, lonGrid=lonGrid, latlonGridSpacing=10, latlonLabels=10)

# open the saved image to show it
im = Image.open(oFileName + '_latlon.png')
plt.imshow(im)

# %%
# make small preview
# 1. Reduce size of the Nansat object ten times
# 2. Make simple grayscaled image with brightness correction
# 3. Resize back to original resolution
n.resize(0.1)
n.write_figure(oFileName + '_preview.png', clim='hist', cmapName='gray')
n.resize()

# open the saved image to show it
im = Image.open(oFileName + '_preview.png')
plt.imshow(im)

# %%
# enlarge the image with bicubic-spline interpolation
n.resize(2, eResampleAlg=3)
n.write_figure(oFileName + '_large.png', clim='hist', cmapName='gray')
n.resize()

# open the saved image to show it
im = Image.open(oFileName + '_large.png')
plt.imshow(im)

# %%
# make KML file with image borders (to be opened in Googe Earth)
n.write_kml(kmlFileName=oFileName + '_preview.kml')

# %%
# make image with map of the file location
n.write_map(oFileName + '_map.png')

# open the saved image to show it
im = Image.open(oFileName + '_map.png')
plt.imshow(im)

# %%
# Make image reprojected onto map of Northern Europe
# 1. Create Domain object. It describes the desired grid of reprojected image:
# projection, resolution, size, etc. In this case it is geographic projection;
# -10 - 30 E, 50 - 70 W; 2000 x 2000 pixels
# 2. Reproject the Nansat object
# 3. Make simple image
dLatlong = Domain("+proj=latlong +datum=WGS84 +ellps=WGS84 +no_defs", "-te 25 70 35 72 -ts 2000 2000")
dLatlong.write_map(oFileName + '_latlong_map.png')
print 'Latlong Domain:', dLatlong
n.reproject(dLatlong)
n.write_figure(oFileName + '_pro_latlon.png')

# open the saved image to show it
im = Image.open(oFileName + '_pro_latlon.png')
plt.imshow(im)
# Out:
# Latlong Domain: Domain:[2000 x 2000]
# ----------------------------------------
# Projection:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563],
#         TOWGS84[0,0,0,0,0,0,0]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433]]
# ----------------------------------------
# Corners (lon, lat):
# 	 ( 25.00,  72.00)  ( 35.00,  72.00)
# 	 ( 25.00,  70.00)  ( 35.00,  70.00)

# %%
# Reprojected image into stereographic projection
# 1. Cancel previous reprojection
# 2. Get corners of the image
# 3. Create Domain with stereographic projection, corner coordinates and resolution 1000m
# 4. Reproject with cubic interpolation
# 5. Write image
n.reproject() # 1.
lons, lats = n.get_corners() # 2.
meanLon = sum(lons, 0.0) / 4.
meanLat = sum(lats, 0.0) / 4.
srsString = "+proj=stere +lon_0=%f +lat_0=%f +k=1 +ellps=WGS84 +datum=WGS84 +no_defs" % (meanLon, meanLat)
extentString = '-lle %f %f %f %f -tr 100 100' % (min(lons), min(lats), max(lons), max(lats))
dStereo = Domain(srsString, extentString) # 3.
dStereo.write_map(oFileName + '_stereo_map.png')
print 'Stereo Domain:', dStereo
n.reproject(dStereo, 2) # 4.
n.write_figure(oFileName + '_pro_stereo.png') # 5.

# open the saved image to show it
im = Image.open(oFileName + '_pro_stereo.png')
plt.imshow(im)
# Out:
# Stereo Domain: Domain:[1401 x 1326]
# ----------------------------------------
# Projection:
# PROJCS["unnamed",
#     GEOGCS["WGS 84",
#         DATUM["WGS_1984",
#             SPHEROID["WGS 84",6378137,298.257223563],
#             TOWGS84[0,0,0,0,0,0,0]],
#         PRIMEM["Greenwich",0],
#         UNIT["degree",0.0174532925199433]],
#     PROJECTION["Stereographic"],
#     PARAMETER["latitude_of_origin",70.945069],
#     PARAMETER["central_meridian",28.983327],
#     PARAMETER["scale_factor",1],
#     PARAMETER["false_easting",0],
#     PARAMETER["false_northing",0]]
# ----------------------------------------
# Corners (lon, lat):
# 	 ( 27.02,  71.54)  ( 30.99,  71.54)
# 	 ( 27.14,  70.35)  ( 30.87,  70.35)

# %%
# Reproject onto grid of another file (destination file is projected)
n2 = Nansat('stere.tif')
n.reproject(n2)
n.write_figure(fileName=oFileName + '_proj_1onto2.png', bands=[1,2,3], clim='hist')

# open the saved image to show it
im = Image.open(oFileName + '_proj_1onto2.png')
plt.imshow(im)

# %%
# Reproject onto grid of another file (destination file is in swath projection)
n.reproject()
n2.reproject(n)
n2.write_figure(fileName=oFileName + '_proj_2onto1.png', bands=[1,2,3], clim='hist')

# open the saved image to show it
im = Image.open(oFileName + '_proj_2onto1.png')
plt.imshow(im)

# %%
# Reproject onto grids of lat/lon
dFromGrids = Domain(lon=lonGrid, lat=latGrid)
n2.reproject(dFromGrids)
n2.write_figure(fileName=oFileName + '_proj_on_grid.png', bands=[1,2,3], clim='hist')

# open the saved image to show it
im = Image.open(oFileName + '_proj_on_grid.png')
plt.imshow(im)

# %%
# reproject onto automatically generated domain
dstDomainAuto = Domain(srs="+proj=latlong +datum=WGS84 +ellps=WGS84 +no_defs", ds=n.raw.dataset)
n.reproject(dstDomainAuto)
n.write_figure(fileName=oFileName + '_proj_1auto.png', bands=[1,2,3], clim='hist')

# open the saved image to show it
im = Image.open(oFileName + '_proj_1auto.png')
plt.imshow(im)

# %%
# Crop
import distancelib
n.reproject()

lons, lats = n.get_corners()
pxlRes = array(distancelib.getPixelResolution(array(lats), array(lons), n.shape(), 'deg'))


srsString = "+proj=longlat +datum=WGS84 +ellps=WGS84 +no_defs"
extentString = '-lle %f %f %f %f -tr %f %f' % (28.5, 70.7, \
                30, 71.5, pxlRes[1], pxlRes[0])
dstDomain = Domain(srs=srsString, ext=extentString)
n.reproject(dstDomain)
n.write_figure(fileName=oFileName + '_proj_1auto.png', bands=[1,2,3], clim='hist')

# open the saved image to show it
im = Image.open(oFileName + '_proj_1auto.png')
plt.imshow(im)

# %%
# export all data into NetCDF format
n.export(oFileName + '_0.nc')

# export one band to GeoTIFF
n.export_band(oFileName + '_2.tif', bandID=2, driver='GTiff')

# %%
# export one band to HDF4
n.export_band(oFileName + '_3.hdf', bandID=2, driver='HDF4Image')
# export fulll Nansat to HDF4
#n.export(oFileName + '_3.hdf', driver='HDF4Image')
import gdal
tst = gdal.Open( oFileName + '_3.hdf')
plt.imshow(tst.GetRasterBand(1).ReadAsArray())
# Once we're done, close properly the dataset
tst = None

# %%
# create new object from given domain and array
# 1. Reproject the current object
# 2. Get array with data
# 2. Create new Nansat object from the given array and for given domain
n.reproject(dStereo)
array = n[1]
nStereo = Nansat(domain=dStereo, array=array, parameters={'name': 'band1'})
print 'Stereo Nansat:', nStereo

# %%
# add band from array to existing object
# 0. Cancel reprojection. Adding bands works only on non-reprojected data
# 1. Get the data from the object and modify
# 2. Add band with modified data to the object
# 3. Check that the band is in the object
n.reproject()
array = n[1] * 10
n.add_band(array=array, parameters={'name': 'new_band', 'about': 'test'})
print 'Nansat with new band:', n

# add band from another file to existing object
n.add_band(fileName='stere.tif', bandID='L_645', parameters={'name': 'L_645_stere'})
print 'Nansat with new band from another file:', n

# %%
# Prepare the image for Google Earth exporting
# reproject image into Lat/Lon WGS84 (Simple Cylindrical) projection
# 1. Cancel previous reprojection
# 2. Get corners of the image and the pixel resolution
# 3. Create Domain with stereographic projection, corner coordinates 1000m
# 4. Reproject
n.reproject()                                                       # 1.
lons, lats = n.get_corners()                                        # 2.
srsString = "+proj=latlong +datum=WGS84 +ellps=WGS84 +no_defs"
extentString = '-lle %f %f %f %f -ts 800 600' % (min(lons), min(lats), max(lons), max(lats))
d = Domain(srs=srsString, ext=extentString)                         # 3.
n.reproject(d)                                                      # 4.
# get array with watermask (landmask)
# it must be done after reprojection!
# 6. Get Nansat object with watermask
# 7. Get array from Nansat object. 0 - land, 1 - water
wm = n.watermask()                                                  # 6.
wmArray = wm[1]                                                     # 7.

# 8. Write the projected image with transparent land mask and image background
# transparentMask: boolean, defult = False
# If True, the masked pixels will be transparent when saving to png
#transparency: int
#transparency of the image background, set for PIL in Figure.save()
#default transparent color is [0,0,0]
n.write_figure(fileName=oFileName + '_proj.png', bands=[1,2,3],
               mask_array=wmArray, mask_lut={0: [128, 128, 128]},
               clim='hist', transparency=[128, 128, 128])           # 8.

# make KML file for the exported image
n.write_kml_image(kmlFileName=oFileName + '.kml', kmlFigureName=oFileName + '_proj.png')

# open the saved image to show it
im = Image.open(oFileName + '_proj.png')
plt.imshow(im)

# %%
# Perform batch averaging of several files
# 1. Create destination Nansat object with desired projection
nMosaic = Nansat(domain=dStereo)
# 2. Perfom averaging
nMosaic.mosaic(['gcps.tif', 'stere.tif'], bands=['L_645', 'L_555', 'L_469'])
# 3. Get mask of non-valid pixels
mask = nMosaic['mask']
# 4. Output averaged data using the mask
nMosaic.write_figure(fileName=oFileName + '_mosaic.png', bands=['L_645', 'L_555', 'L_469'], clim='hist',
                        mask_array=mask, mask_lut={0:[128,128,128]})

# open the saved image to show it
im = Image.open(oFileName + '_mosaic.png')
plt.imshow(im)

# %%
print 'Tutorial completed successfully.'
print 'Output files are found here:\n' + oFileName

# %% [markdown]
# ##

# %% [markdown]
# ##
